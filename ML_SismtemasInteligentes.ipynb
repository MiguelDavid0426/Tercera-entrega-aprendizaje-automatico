# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelDavid0426/Tercera-entrega-aprendizaje-automatico/blob/main/ML_SismtemasInteligentes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias
import cv2
from google.colab.patches import cv2_imshow
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import shutil
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
#Montar google drive
from google.colab import drive
drive.mount('/content/drive')

% cd /content/drive/MyDrive/Colab Notebooks
#Acá debemos cargar los archivos de imagenes y etiquetas en google drive

#Cargar etiquetas
lab=np.load('labels.npy')

#Cargar imagenes
img=np.load('Imagenes_gris_60.npy')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks

# %%
x_train, x_test, y_train, y_test = train_test_split(img, lab, test_size=0.2)
print(x_train.shape)
print(x_test.shape)
# Out:
# (1600, 60, 60)
# (400, 60, 60)

# %%
train_X = x_train.reshape(-1, 60,60, 1)
test_X = x_test.reshape(-1, 60,60, 1)
train_X.shape, test_X.shape
# Out:
# ((1600, 60, 60, 1), (400, 60, 60, 1))

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X / 255.
test_X = test_X / 255.

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.5,1,1.5,2],'epsilon':[0.05,0.1,0.15,0.2],'kernel':['linear','poly','rbf','sigmoid']} 

svr=svm.SVR()
model=GridSearchCV(svr,param_grid,scoring='neg_mean_absolute_error')

# %%
nsamples, nx, ny, nz = train_X.shape
nsamples_t, nx_t, ny_t, nz_t = test_X.shape

# %%
d2_train_dataset = train_X.reshape((nsamples,nx*ny*nz))
d2_test_dataset = test_X.reshape((nsamples_t,nx_t*ny_t*nz_t))

# %%
model.fit(d2_train_dataset,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
y_pred=model.predict(d2_test_dataset)

#### Error cuadrático medio
print("Error cuadrático medio: ", mean_squared_error(y_test, y_pred)," (the best value is 0)")

#### Puntaje R², el coeficiente de determinación
print("R cuadrado: ", r2_score(y_test, y_pred)," (the best value is 1)")

#### Error absoluto medio
print("MAE: ", mean_absolute_error(y_test, y_pred)," (the best value is 0)")
# Out:
# Error cuadrático medio:  5.173317345269331  (the best value is 0)
# R cuadrado:  0.8840790967604424  (the best value is 1)
# MAE:  1.8556167045079548  (the best value is 0)

# %%
pd.DataFrame(model.cv_results_)

# %% [markdown]
# Dave Prueba 1

# %%
# Definir el algoritmo a utilizar
svr = SVR(kernel = "sigmoid", C = 0.5, epsilon =0.2)

# Entrenar el modelo
svr.fit(d2_train_dataset,y_train)

# Realizar predicciones 
y_pred=svr.predict(d2_test_dataset)

#### Error cuadrático medio
#print("Error cuadrático medio: ", mean_squared_error(y_test, y_pred)," (the best value is 0)")

#### Puntaje R², el coeficiente de determinación
#print("R cuadrado: ", r2_score(y_test, y_pred)," (the best value is 1)")

#### Error absoluto medio
print("MAE: ", mean_absolute_error(y_test, y_pred)," (the best value is 0)")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MAE:  5.582372907906481  (the best value is 0)
